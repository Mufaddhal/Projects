# %% [markdown]
# # NLP LAB EXERCISE
# ### Zaidan Mufaddhal - AIU20092029

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
def get_only_text(url):
    page = urlopen(url)
    soup = BeautifulSoup(page)
    text = ''.join(map(lambda p: p.text, soup.find_all('p')))
    print(text)
    return soup.title.text, text

# %%
url = 'https://en.wikipedia.org/wiki/Data_science'

# %%
text = get_only_text(url)
# Out:
# Data science is an interdisciplinary academic field [1]
# that uses statistics, scientific computing, scientific methods, processes, algorithms and systems to extract or extrapolate knowledge and insights from noisy, structured and unstructured data.[2]
# Data science is a "concept to unify statistics, data analysis, informatics, and their related methods" in order to "understand and analyse actual phenomena" with data.[3] It uses techniques and theories drawn from many fields within the context of mathematics, statistics, computer science, information science, and domain knowledge.[4] However, data science is different from computer science and information science. Turing Award winner Jim Gray imagined data science as a "fourth paradigm" of science (empirical, theoretical, computational, and now data-driven) and asserted that "everything about science is changing because of the impact of information technology" and the data deluge.[5][6]
# ...

# %%
# convert text to string format
text = str(text)

# %% [markdown]
# ## 1. Tokenization

# %% [markdown]
# ### 1.1 Sentence Tokenization

# %%
import nltk
from nltk import sent_tokenize
from nltk import word_tokenize

# %%
sentence = sent_tokenize(text)

# %%
sentence
# Out:
# ["('Data science - Wikipedia', '\\nData science is an interdisciplinary academic field [1]\\nthat uses statistics, scientific computing, scientific methods, processes, algorithms and systems to extract or extrapolate knowledge and insights from noisy, structured and unstructured data.",
#  '[2]\\nData science is a "concept to unify statistics, data analysis, informatics, and their related methods" in order to "understand and analyse actual phenomena" with data.',
#  '[3] It uses techniques and theories drawn from many fields within the context of mathematics, statistics, computer science, information science, and domain knowledge.',
#  '[4] However, data science is different from computer science and information science.',
# ...

# %% [markdown]
# ### 1.2 Word Tokenization

# %%
words = word_tokenize(text)

# %%
print(words)
# Out:
# ['(', "'Data", 'science', '-', 'Wikipedia', "'", ',', "'\\nData", 'science', 'is', 'an', 'interdisciplinary', 'academic', 'field', '[', '1', ']', '\\nthat', 'uses', 'statistics', ',', 'scientific', 'computing', ',', 'scientific', 'methods', ',', 'processes', ',', 'algorithms', 'and', 'systems', 'to', 'extract', 'or', 'extrapolate', 'knowledge', 'and', 'insights', 'from', 'noisy', ',', 'structured', 'and', 'unstructured', 'data', '.', '[', '2', ']', '\\nData', 'science', 'is', 'a', '``', 'concept', 'to', 'unify', 'statistics', ',', 'data', 'analysis', ',', 'informatics', ',', 'and', 'their', 'related', 'methods', "''", 'in', 'order', 'to', '``', 'understand', 'and', 'analyse', 'actual', 'phenomena', "''", 'with', 'data', '.', '[', '3', ']', 'It', 'uses', 'techniques', 'and', 'theories', 'drawn', 'from', 'many', 'fields', 'within', 'the', 'context', 'of', 'mathematics', ',', 'statistics', ',', 'computer', 'science', ',', 'information', 'science', ',', 'and', 'domain', 'knowledge', '.',
# ...

# %% [markdown]
# ### 1.3 Length of The Sentence and Word

# %%
print(len(sentence))
# Out:
# 45

# %%
print(len(words))
# Out:
# 1230

# %% [markdown]
# ## 2. Frequency of Distribution of The Words

# %%
from nltk.probability import FreqDist

# %%
freDis = FreqDist(words)

# %%
freDis.most_common(20)
# Out:
# [(',', 74),
#  ('data', 46),
#  ('.', 44),
#  ('and', 43),
#  ('[', 42),
#  (']', 42),
#  ('science', 33),
#  ('the', 33),
#  ('of', 27),
#  ('a', 20),
#  ('statistics', 18),
#  ('to', 18),
#  ('in', 16),
#  ('is', 14),
#  ('``', 14),
#  ("''", 14),
#  ('as', 11),
#  ('that', 11),
#  ('from', 10),
#  ('it', 9)]

# %% [markdown]
# ### 2.1 Plot The Frequency Graph

# %%
import matplotlib.pyplot as plt

# %%
freDis.plot(20)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# ### 2.2 Remove Punctuation Marks

# %%
wordPunc = []

# %%
for a in words:
    if a.isalpha():
        wordPunc.append(a.lower())

# %%
print(wordPunc)
# Out:
# ['science', 'wikipedia', 'science', 'is', 'an', 'interdisciplinary', 'academic', 'field', 'uses', 'statistics', 'scientific', 'computing', 'scientific', 'methods', 'processes', 'algorithms', 'and', 'systems', 'to', 'extract', 'or', 'extrapolate', 'knowledge', 'and', 'insights', 'from', 'noisy', 'structured', 'and', 'unstructured', 'data', 'science', 'is', 'a', 'concept', 'to', 'unify', 'statistics', 'data', 'analysis', 'informatics', 'and', 'their', 'related', 'methods', 'in', 'order', 'to', 'understand', 'and', 'analyse', 'actual', 'phenomena', 'with', 'data', 'it', 'uses', 'techniques', 'and', 'theories', 'drawn', 'from', 'many', 'fields', 'within', 'the', 'context', 'of', 'mathematics', 'statistics', 'computer', 'science', 'information', 'science', 'and', 'domain', 'knowledge', 'however', 'data', 'science', 'is', 'different', 'from', 'computer', 'science', 'and', 'information', 'science', 'turing', 'award', 'winner', 'jim', 'gray', 'imagined', 'data', 'science', 'as', 'a', 'fourth
# ...

# %% [markdown]
# ### 2.3 Plot Graph Without Punctuation Marks

# %%
wordNoPunc = FreqDist(wordPunc)

# %%
wordNoPunc.most_common(20)
# Out:
# [('data', 55),
#  ('and', 43),
#  ('science', 38),
#  ('the', 36),
#  ('of', 27),
#  ('in', 24),
#  ('a', 21),
#  ('statistics', 18),
#  ('to', 18),
#  ('is', 14),
#  ('as', 12),
#  ('that', 11),
#  ('from', 10),
#  ('it', 10),
#  ('for', 9),
#  ('on', 8),
#  ('an', 7),
#  ('field', 7),
#  ('with', 7),
#  ('information', 7)]

# %%
wordNoPunc.plot(20)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# ### 2.4 List of Stopwords

# %%
from nltk.corpus import stopwords

# %%
stopwords = stopwords.words("english")

# %%
print(stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %% [markdown]
# ### 2.5 Remove Stopwords

# %%
CleanWords = []

# %%
for w in wordNoPunc:
    if w not in docu:
        CleanWords.append(w)

print(CleanWords)
# Out:
# ['data', 'and', 'science', 'the', 'of', 'in', 'a', 'statistics', 'to', 'is', 'as', 'that', 'from', 'it', 'for', 'on', 'an', 'field', 'with', 'information', 'knowledge', 'new', 'name', 'analysis', 'statistical', 'or', 'computer', 'by', 'he', 'interdisciplinary', 'computing', 'systems', 'insights', 'their', 'because', 'scientist', 'problems', 'be', 'learning', 'digital', 'university', 'has', 'jeff', 'used', 'term', 'at', 'was', 'uses', 'scientific', 'methods', 'algorithms', 'concept', 'related', 'techniques', 'many', 'mathematics', 'however', 'technology', 'focused', 'large', 'range', 'application', 'domains', 'such', 'visualization', 'design', 'should', 'american', 'three', 'professional', 'argued', 'not', 'writes', 'emphasizes', 'quantitative', 'columbia', 'described', 'datasets', 'which', 'modern', 'lecture', 'chinese', 'academy', 'sciences', 'beijing', 'wu', 'first', 'alternative', 'later', 'discipline', 'been', 'became', 'definition', 'still', 'would', 'help', 'collection', 'minin
# ...

# %%
print(len(CleanWords))
# Out:
# 396

# %%
freDist = FreqDist(CleanWords)
freDist.most_common(20)
# Out:
# [('data', 1),
#  ('and', 1),
#  ('science', 1),
#  ('the', 1),
#  ('of', 1),
#  ('in', 1),
#  ('a', 1),
#  ('statistics', 1),
#  ('to', 1),
#  ('is', 1),
#  ('as', 1),
#  ('that', 1),
#  ('from', 1),
#  ('it', 1),
#  ('for', 1),
#  ('on', 1),
#  ('an', 1),
#  ('field', 1),
#  ('with', 1),
#  ('information', 1)]

# %%
freDist.plot(20)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# ### 3. Word Cloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
wordcloud = WordCloud(background_color='white').generate(text)

# %%
plt.figure(figsize = (12,12))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
